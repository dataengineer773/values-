# %%
d = dict(a = 10, b = 20, c = 30)

# %%
values = d.values()

# %%
values
# Out:
# dict_values([10, 20, 30])

# %%
len(values)
# Out:
# 3

# %%
list(values)
# Out:
# [10, 20, 30]

# %%
reversed(values)
